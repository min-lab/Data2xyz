# %%
from bokeh.io import output_notebook, push_notebook, show
from bokeh.models import Span
from bokeh.plotting import figure

import pandas as pd
import glob
from pyexcelerate import Workbook
from pathlib import Path

# %%
o_dir = './excel/'
skip_file = ['0504sitrightdrinkh2o.csv','0504stand_3min.csv']

# %%
def cut_data(data_df):
    fragment = []
    silence = False
    data_filtered = (data_df["ax"] < 0.3) & (data_df["ax"] > -0.3)
    cnt = 0
    for idx in range(len(data_filtered)):
        if data_filtered[idx]:
            cnt = cnt + 1
        else:
            cnt = 0
            if silence:
                fragment.append(idx - 1)
                silence = False
        if cnt > 300:
            silence = True
            if idx == len(data_filtered)-1:
                fragment.append(idx)
    silence = False
    data_filtered = (data_df["ax"] < 0.3) & (data_df["ax"] > -0.3)
    cnt = 0
    for idx in reversed(range(len(data_filtered))):
        if data_filtered[idx]:
            cnt = cnt + 1
        else:
            cnt = 0
            if silence:
                fragment.append(idx + 1)
                silence = False
        if cnt > 300:
            silence = True
            if idx == 0:
                fragment.append(idx)
    fragment.sort()
    return fragment

# %%
def show_data(data_df, fragment):
    output_notebook()
    p = figure(
        title="origin",
        x_axis_label="time",
        y_axis_label="ax",
        plot_width=1500,
        plot_height=800,
    )
    p.line(data_df.time, data_df.ax, legend_label="Amplitude", line_width=2)
    for idx in fragment:
        line = data_df.time[idx]
        vline = Span(
            location=line,
            dimension="height",
            line_color="red",
            line_dash="dashed",
            line_width=3,
        )
        p.add_layout(vline)
    handle = show(p, notebook_handle=True)
    push_notebook(handle=handle)

# %%
Path(o_dir).mkdir(parents=True, exist_ok=True)
for file in glob.glob('*.csv'):
    data = pd.read_csv(file).drop(columns=['Unnamed: 7'])
    file_cnt = 0
    wb = Workbook()
    if file in skip_file:
        print("Write" + o_dir + '/' + file[:-4] + ".xlsx, sheet_name:" + "raw")
        output_data = [
                data.columns.tolist(),
            ] + data.values.tolist()
        wb.new_sheet("raw", data=output_data)
        wb.save(o_dir + file[:-4] + ".xlsx")
    else:
        fragment = cut_data(data)
        show_data(data, fragment)
        for idx in range(0, len(fragment) - 3, 2):
            file_cnt = file_cnt + 1
            print("Write" + o_dir + file[:-4] + ".xlsx, sheet_name:" + "raw_" + str(file_cnt))
            file_idx_s = fragment[idx]
            file_idx_e = fragment[idx + 3]
            output_data = [
                data[file_idx_s:file_idx_e].columns.tolist(),
            ] + data[file_idx_s:file_idx_e].values.tolist()
            wb.new_sheet("raw_" + str(file_cnt), data=output_data)
            wb.save(o_dir + file[:-4] + ".xlsx")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="72404">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="3c093067-969a-4dfa-a4c1-6d0f65db75b6" data-root-id="72405"></div>
# Write./excel/0504biump10.xlsx, sheet_name:raw_1
# Write./excel/0504biump10.xlsx, sheet_name:raw_2
# Write./excel/0504biump10.xlsx, sheet_name:raw_3
# Write./excel/0504biump10.xlsx, sheet_name:raw_4
# Write./excel/0504biump10.xlsx, sheet_name:raw_5
# Write./excel/0504biump10.xlsx, sheet_name:raw_6
# Write./excel/0504biump10.xlsx, sheet_name:raw_7
# Write./excel/0504biump10.xlsx, sheet_name:raw_8
# Write./excel/0504biump10.xlsx, sheet_name:raw_9
# Write./excel/0504biump10.xlsx, sheet_name:raw_10
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="73482">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="059b1960-9baa-4b11-bb71-205bfa8de816" data-root-id="73483"></div>
# Write./excel/0504clk20.xlsx, sheet_name:raw_1
# Write./excel/0504clk20.xlsx, sheet_name:raw_2
# Write./excel/0504clk20.xlsx, sheet_name:raw_3
# Write./excel/0504clk20.xlsx, sheet_name:raw_4
# Write./excel/0504clk20.xlsx, sheet_name:raw_5
# Write./excel/0504clk20.xlsx, sheet_name:raw_6
# Write./excel/0504clk20.xlsx, sheet_name:raw_7
# Write./excel/0504clk20.xlsx, sheet_name:raw_8
# Write./excel/0504clk20.xlsx, sheet_name:raw_9
# Write./excel/0504clk20.xlsx, sheet_name:raw_10
# Write./excel/0504clk20.xlsx, sheet_name:raw_11
# Write./excel/0504clk20.xlsx, sheet_name:raw_12
# Write./excel/0504clk20.xlsx, sheet_name:raw_13
# Write./excel/0504clk20.xlsx, sheet_name:raw_14
# Write./excel/0504clk20.xlsx, sheet_name:raw_15
# Write./excel/0504clk20.xlsx, sheet_name:raw_16
# Write./excel/0504clk20.xlsx, sheet_name:raw_17
# Write./excel/0504clk20.xlsx, sheet_name:raw_18
# Write./excel/0504clk20.xlsx, sheet_name:raw_19
# Write./excel/0504clk20.xlsx, sheet_name:raw_20
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="74588">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6a30cd25-5676-405d-901f-ba9bb3cbeb1d" data-root-id="74589"></div>
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_1
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_2
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_3
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_4
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_5
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_6
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_7
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_8
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_9
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_10
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_11
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_12
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_13
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_14
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_15
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_16
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_17
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_18
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_19
# Write./excel/0504crouchright20.xlsx, sheet_name:raw_20
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="75702">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="50e6b045-3c71-4664-9899-9efc7dc37fec" data-root-id="75703"></div>
# Write./excel/0504jump10.xlsx, sheet_name:raw_1
# Write./excel/0504jump10.xlsx, sheet_name:raw_2
# Write./excel/0504jump10.xlsx, sheet_name:raw_3
# Write./excel/0504jump10.xlsx, sheet_name:raw_4
# Write./excel/0504jump10.xlsx, sheet_name:raw_5
# Write./excel/0504jump10.xlsx, sheet_name:raw_6
# Write./excel/0504jump10.xlsx, sheet_name:raw_7
# Write./excel/0504jump10.xlsx, sheet_name:raw_8
# Write./excel/0504jump10.xlsx, sheet_name:raw_9
# Write./excel/0504jump10.xlsx, sheet_name:raw_10
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="76804">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="55057927-f4cf-466b-a186-315dfff610bd" data-root-id="76805"></div>
# Write./excel/0504nclk20.xlsx, sheet_name:raw_1
# Write./excel/0504nclk20.xlsx, sheet_name:raw_2
# Write./excel/0504nclk20.xlsx, sheet_name:raw_3
# Write./excel/0504nclk20.xlsx, sheet_name:raw_4
# Write./excel/0504nclk20.xlsx, sheet_name:raw_5
# Write./excel/0504nclk20.xlsx, sheet_name:raw_6
# Write./excel/0504nclk20.xlsx, sheet_name:raw_7
# Write./excel/0504nclk20.xlsx, sheet_name:raw_8
# Write./excel/0504nclk20.xlsx, sheet_name:raw_9
# Write./excel/0504nclk20.xlsx, sheet_name:raw_10
# Write./excel/0504nclk20.xlsx, sheet_name:raw_11
# Write./excel/0504nclk20.xlsx, sheet_name:raw_12
# Write./excel/0504nclk20.xlsx, sheet_name:raw_13
# Write./excel/0504nclk20.xlsx, sheet_name:raw_14
# Write./excel/0504nclk20.xlsx, sheet_name:raw_15
# Write./excel/0504nclk20.xlsx, sheet_name:raw_16
# Write./excel/0504nclk20.xlsx, sheet_name:raw_17
# Write./excel/0504nclk20.xlsx, sheet_name:raw_18
# Write./excel/0504nclk20.xlsx, sheet_name:raw_19
# Write./excel/0504nclk20.xlsx, sheet_name:raw_20
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="77934">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c5bdf8f6-6d22-4e03-84c9-0002b5790047" data-root-id="77935"></div>
# Write./excel/0504shake_10.xlsx, sheet_name:raw_1
# Write./excel/0504shake_10.xlsx, sheet_name:raw_2
# Write./excel/0504shake_10.xlsx, sheet_name:raw_3
# Write./excel/0504shake_10.xlsx, sheet_name:raw_4
# Write./excel/0504shake_10.xlsx, sheet_name:raw_5
# Write./excel/0504shake_10.xlsx, sheet_name:raw_6
# Write./excel/0504shake_10.xlsx, sheet_name:raw_7
# Write./excel/0504shake_10.xlsx, sheet_name:raw_8
# Write./excel/0504shake_10.xlsx, sheet_name:raw_9
# Write./excel/0504shake_10.xlsx, sheet_name:raw_10
# Write./excel/0504shake_10.xlsx, sheet_name:raw_11
# Write./excel//0504sitrightdrinkh2o.xlsx, sheet_name:raw
# Write./excel//0504stand_3min.xlsx, sheet_name:raw
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="79054">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="40cb8c8e-6dc9-424b-90dd-b8d605877ba8" data-root-id="79055"></div>
# Write./excel/0504waist_20.xlsx, sheet_name:raw_1
# Write./excel/0504waist_20.xlsx, sheet_name:raw_2
# Write./excel/0504waist_20.xlsx, sheet_name:raw_3
# Write./excel/0504waist_20.xlsx, sheet_name:raw_4
# Write./excel/0504waist_20.xlsx, sheet_name:raw_5
# Write./excel/0504waist_20.xlsx, sheet_name:raw_6
# Write./excel/0504waist_20.xlsx, sheet_name:raw_7
# Write./excel/0504waist_20.xlsx, sheet_name:raw_8
# Write./excel/0504waist_20.xlsx, sheet_name:raw_9
# Write./excel/0504waist_20.xlsx, sheet_name:raw_10
# Write./excel/0504waist_20.xlsx, sheet_name:raw_11
# Write./excel/0504waist_20.xlsx, sheet_name:raw_12
# Write./excel/0504waist_20.xlsx, sheet_name:raw_13
# Write./excel/0504waist_20.xlsx, sheet_name:raw_14
# Write./excel/0504waist_20.xlsx, sheet_name:raw_15
# Write./excel/0504waist_20.xlsx, sheet_name:raw_16
# Write./excel/0504waist_20.xlsx, sheet_name:raw_17
# Write./excel/0504waist_20.xlsx, sheet_name:raw_18
# Write./excel/0504waist_20.xlsx, sheet_name:raw_19
# Write./excel/0504waist_20.xlsx, sheet_name:raw_20
