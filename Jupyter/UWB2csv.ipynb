# %%
from bokeh.io import output_notebook, push_notebook, show, export_png
from bokeh.models import Span
from bokeh.plotting import figure
import pandas as pd
from pathlib import Path

# %%
i_file = "../Data/20200502_Lab/UWB/uwb_20200502_2.csv"
o_dir = "../Data/20200502_Lab/UWB/uwb_20200502_2/"
image_name = 'UWB數據.png'
csv_name = 'uwb.csv'

# %%
data = pd.read_csv(i_file)
data = data[(data['Duration'] > 2.75) & (data['Duration'] < 11.25)]
result = pd.DataFrame()
for name, group in data.groupby('Duration'):
    if len(group) >= 4:
        group = group.sort_values(by='Ranging')[0:4]
        result = result.append(group)
result = result.reset_index(drop=True)

# %%
exist = []
nexist = []
exist_time = []
nexist_time = []
for num in np.arange(2.75,11.25,0.5):
    interval = (result['Duration'] > num) & (result['Duration'] < num + 0.5)
    if(len(result['Duration'][interval])):
        exist.append(1)
        exist_time.append(num+0.25)
    else:
        nexist.append(0)
        nexist_time.append(num+0.25)
output_notebook()
p = figure(
    title="UWB數據",
    x_axis_label="時間(s)",
    y_axis_label="可使用(T/F)",
    plot_width=1200,
    plot_height=800,
)
p.circle(exist_time, exist, color='red', radius=0.1)
p.circle(nexist_time, nexist, color='blue', radius=0.1)
p.xaxis.ticker = list(np.arange(3,11.5,0.5))
handle = show(p, notebook_handle=True)
push_notebook(handle=handle)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9583">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8e544bfc-297c-4c2a-8724-841b2b4ae6d6" data-root-id="9584"></div>

# %%
Path(o_dir).mkdir(parents=True, exist_ok=True)
export_png(p, filename= o_dir + image_name)
result.to_csv(o_dir + csv_name, index=False)
